# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %% [markdown]
# # Expore data from regulation task

# %%
current_path = os.path.abspath(os.path.curdir)
data_folder = os.path.join(current_path, 'lifecycles_data')

data = np.load(os.path.join(data_folder, 'dfg.npy'))
# Out:
# [-0.013  0.039  0.047  0.073  0.145  0.22   0.288  0.351  0.392  0.464
#   0.5    0.5    0.5    0.5    0.5    0.461  0.462  0.445  0.396  0.306
#   0.216  0.205  0.138  0.094  0.001 -0.045 -0.093 -0.157 -0.248 -0.296
#  -0.353 -0.47  -0.5   -0.5   -0.5   -0.5   -0.5   -0.5   -0.5   -0.5
#  -0.5   -0.5   -0.5   -0.5   -0.5   -0.5   -0.5   -0.5   -0.5   -0.5
#  -0.5   -0.5   -0.5   -0.5   -0.5   -0.5   -0.5   -0.496 -0.449 -0.443
#  -0.416 -0.339 -0.281 -0.234 -0.132 -0.051  0.067  0.197  0.29   0.397
#   0.5    0.5    0.5    0.5    0.5    0.5    0.5    0.5    0.5    0.439
#   0.405  0.376  0.331  0.289  0.273  0.209  0.158  0.031 -0.059 -0.142
#  -0.213 -0.266 -0.331 -0.404 -0.48  -0.5   -0.5   -0.5   -0.5   -0.5  ]

# %%
t = range(len(data[0]))
plt.subplot(211)
plt.plot(t, data[0])
plt.plot(data[1])
plt.subplot(212)
plt.plot(data[2])
plt.plot(data[3])
plt.plot(data[4])

plt.show()
